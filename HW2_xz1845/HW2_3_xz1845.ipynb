# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
print os.environ.get('DFDATA')
# Out:
# /gws/open/NYCOpenData/nycopendata/data

# %%
data_location = os.environ.get('DFDATA') + '/zkky-n5j3/1414246141/zkky-n5j3'
data = pd.read_csv(data_location)
data.head()
# Out:
#    Neversink Date                Neversink Elevation  Neversink Storage  \
# 0  03/01/2005 04:00:00 PM +0000              1440.21              35570
# 1  03/02/2005 04:00:00 PM +0000              1440.22              35575
# 2  03/03/2005 04:00:00 PM +0000              1440.21              35570
# 3  03/04/2005 04:00:00 PM +0000              1440.21              35570
# 4  03/05/2005 04:00:00 PM +0000              1440.21              35570
#
#       Rondout Date               Rondout Elevation  Rondout Storage  \
# 0  03/01/2005 04:00:00 PM +0000             835.10          46757.0
# 1  03/02/2005 04:00:00 PM +0000             834.98          46678.0
# 2  03/03/2005 04:00:00 PM +0000             834.84          46585.0
# 3  03/04/2005 04:00:00 PM +0000             834.85          46592.0
# 4  03/05/2005 04:00:00 PM +0000             834.88          46612.0
#
#     Schoharie Date               Schoharie Elevation  Schoharie Storage  \
# ...

# %%
data_2 = data.drop(data.columns.values.tolist()[3:21], axis = 1)
data_2 = data_2.drop(data.columns.values.tolist()[0], axis = 1)

# %%
data_2
# Out:
#       Neversink Elevation  Neversink Storage
# 0                 1440.21              35570
# 1                 1440.22              35575
# 2                 1440.21              35570
# 3                 1440.21              35570
# 4                 1440.21              35570
# 5                 1440.21              35570
# 6                 1440.21              35570
# 7                 1440.24              35585
# 8                 1440.22              35575
# 9                 1440.22              35575
# 10                1440.22              35575
# 11                1440.22              35575
# 12                1440.21              35570
# 13                1440.20              35566
# 14                1440.20              35566
# 15                1440.18              35556
# 16                1440.18              35556
# 17                1440.18              35556
# 18                1440.18              35556
# 19                1440.18              35556
# ...

# %%
data_2.plot.scatter('Neversink Elevation', 'Neversink Storage', label = 'Observation')
plt.legend(loc = 4)
plt.title('Elevation vs Storage at Neversink')
plt.text(1400, 10000, 'Figure 1: Elevation vs Storage at Neversink')
plt.show()
